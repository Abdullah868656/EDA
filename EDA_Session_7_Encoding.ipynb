# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r'E:\my work\omkar sir batch\data set\Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **Encoding**
#
# - Encoding means covert categorical columns data to numerical data
#
# - Because ML models Expect the data should be in NUmerical format
#
# - ML models developed by math algorithms
#
# - It is very very important to apply encoding
#
# - The following methods are
#
#     - map
#
#     - np.where
#
#     - one hot encoding
#
#     - Lable Encoder

# %% [markdown]
# **Map**
#
# - map is one method to convert categorical values to numerical
#
# - Take one categorical column
#
# - Get the unique lables first
#
# - make a dictionary with assign a number to each lable
#
# - for example case_status hads teo lables
#
#     - Certified
#
#     - Denied
#
# - Assing 0 to Certified , 1to Denied
#
# - Create a dixtionary lables as keys, number as values only
#
# - {'Certified':0,'Denied':1}

# %%
# step-1: read the columns
# step-2: get the unique lables
# step-3: make a dictionary
# step-4: apply the map

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}

# %%
visa_df=pd.read_csv(r'E:\my work\omkar sir batch\data set\Visadataset.csv')
unique_lables=visa_df['case_status'].unique()
list1=[i for i in range(len(unique_lables))]
unique_lables,list1
dict1=dict(zip(sorted(unique_lables),list1))
dict1
visa_df ['case_status']=visa_df ['case_status'].map(dict1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
dict1=dict(zip(sorted(unique_lables),list1))
dict1
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
{key:va;ues for ,value in zip(unique_lables,list1)}

# %%
visa_df=pd.read_csv(r'E:\my work\omkar sir batch\data set\Visadataset.csv')
cat_columns=visa_df.select_dtypes(include='object').columns
for i in cat_columns:
    unique_lables=visa_df[i].unique()
    list1=[i for i in range(len(unique_lables))]
    unique_lables,list1
    dict1=dict(zip(sorted(unique_lables),list1))
    dict1
    visa_df [i]=visa_df [i].map(dict1)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
**LableEncoder**

- Lableencoder is a method to covert categorical data to numerical data

- LablesEncoder is a same way , how we did in the the above

- the for loop map method we explored

- but the lableEncoder also do the same 

- IT is under **skleran-learn** we usually called as **sklearn**

- Under 



- sklearn

    - reprocessing
      - LableEncoder
-

# %%
visa_df=pd.read_csv(r'E:\my work\omkar sir batch\data set\Visadataset.csv')

# %%
# step-1 : read the package /load the method
from sklearn.preprocessing import LabelEncoder
#step-2:save tha package /call the methods
le=LabelEncoder()
# step-3:apply fit transform on data
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r'E:\my work\omkar sir batch\data set\Visadataset.csv')

# %%
# step-1 : read the package /load the method
from sklearn.preprocessing import LabelEncoder
visa_df=pd.read_csv(r'E:\my work\omkar sir batch\data set\Visadataset.csv')
cat_columns=visa_df.select_dtypes(include='object').columns
le=LabelEncoder()
for i in cat_columns:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
**fit and transform**

- fit means develop the logic

- transform means process the logic

- if we observe in map method first we developed dictionary logic

- thats we apply that dictionary

# %% [markdown]
# **np.where**

# %% [markdown]
# - using np.where also we can change the Categorical data to numerical
#
# - But np.where is only for binary condition
#
# - np.where is same as if-else
#
# - if condition is True  : will apply True value
#
# - if condition is False : will apply False value
#
# - so np.where use for only binary lables
#
# - A columns should have only two unique lables

# %%
# value =='cerftified'  replace with 0
# otherwise 1
visa_df=pd.read_csv(r'E:\my work\omkar sir batch\data set\Visadataset.csv')
con=visa_df['case_status']=='Certified'
visa_df['cas_status']=np.where (con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
**One hot encoder**

- One hot means if one will bw ON , another will be OFF

- On represents with 1

- OFF represents with 0

- for example case status has two unqiue lables

    - certified

    - Denied

- One hot encoder create new columna which
